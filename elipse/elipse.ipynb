# %%
from matplotlib.patches import Ellipse
import matplotlib as mpl
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import random
import pandas as pd
import glob

# %%
mean1 = np.random.uniform(low=-180, high=180, size=(100,))
mean2 = np.random.uniform(low=-180, high=180, size=(100,))
width = np.random.uniform(low=-180, high=180, size=(100,))
height = np.random.uniform(low=-180, high=180, size=(100,))
angle = np.random.uniform(low=0, high=180, size=(100,))

# %%
data = {'mean1':mean1, 'mean2':mean2, 'width':width, 'height':height, 'angle':angle}

# %%
df = pd.DataFrame(data)

# %%
def elipse(mean, width, height, angle, cont):
    ell = mpl.patches.Ellipse(xy=mean, width=width, height=height, angle = 180+angle, facecolor='w', edgecolor='b')
    fig, ax = plt.subplots()

    ax.add_patch(ell)
    ax.set_aspect('equal')
    ax.autoscale()
    #ax.grid()
    plt.savefig("{}elipse.png".format(cont))
    plt.show()

# %%
cont = 300
for d in df.values:
    elipse([d[0],d[1]], d[2], d[3], d[4], cont)
    cont += 1

# %%
def createTest(data, nameFile):
    file = open(nameFile, 'w')
    for i in glob.glob(str(data)+'*.png'):
        file.writelines(i+',1'+'\n')
    print(nameFile + ' criado')
    file.close()
    
createTest('', 'elipse.csv')
# Out:
# elipse.csv criado
